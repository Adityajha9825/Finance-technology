# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("/content/drive/MyDrive/homeprices.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3400  625000
# 4  3600  705000
# 5  4000  725000
# 6  5000  856000

# %%
df.shape
# Out:
# (7, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    7 non-null      int64
#  1   price   7 non-null      int64
# dtypes: int64(2)
# memory usage: 240.0 bytes

# %%
df.isnull()
# Out:
#     area  price
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False
# 5  False  False
# 6  False  False

# %%
df.isnull().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
plt.plot(df.area,df.price)
plt.xlabel("area")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
x=df.drop("price", axis=1)

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3400
# 4  3600
# 5  4000
# 6  5000

# %%
y=df.price

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    625000
# 4    705000
# 5    725000
# 6    856000
# Name: price, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#step to create machine learning regression model
model= LinearRegression()

# %%
#Step to create training the machine learning model
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([135.4375])

# %%
model.intercept_
# Out:
# 182450.00000000006

# %%
y_predict=model.predict(x)
y_predict
# Out:
# array([534587.5, 588762.5, 615850. , 642937.5, 670025. , 724200. ,
#        859637.5])

# %%
from sklearn.metrics import r2_score
print("R2score", r2_score(y,y_predict))
# Out:
# R2score 0.9655250474960728
